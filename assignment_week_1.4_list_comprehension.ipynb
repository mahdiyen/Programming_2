# %% [markdown]
# # Exercise 1: refactoring your own code

# %%
import json
import linecache as lc

# %%
class CsvConverter:
    def __init__(self,file_name, header):
        self.file_name = file_name
        self.header = header
        self.keys = self.header.split(',')

    
    def convert_csv_to_json(self,lines):
        json_list=[]
        for line in lines:
            try:
                assert len(line) == len(self.keys)

                json_dict = {key: value for key, value in zip(self.keys, line)}
                json_list.append(json_dict)
            except AssertionError:
                print ("Number of items in line does not match the number of keys in header.")
            
        return json.dumps(json_list)

# %%
# header = 'first,second,third'
# c = CsvConverter('dSST.csv',header)
# lines =[[1,2,3],[4,5,6]]
# c.convert_csv_to_json(lines)

# %%
class Reader:
    
    def __init__(self, location, csvconverter):
        self.location = location
        self.csvconverter = csvconverter
        self.starter =2
        
    def get_lines(self): 
        lines_list= [lc.getline(self.csvconverter.file_name,i).strip().split(',') for i in range(self.starter, self.starter + 4)]
        self.starter = self.starter + 4
        return (self.csvconverter.convert_csv_to_json(lines_list))

# %%
header = lc.getline('dSST.csv',1).strip()
r = Reader('dSST.csv', CsvConverter('dSST.csv',header))

# %%
r.get_lines()
# Out:
# '[{"Year": "1889", "Jan": "-.08", "Feb": ".17", "Mar": ".07", "Apr": ".10", "May": ".00", "Jun": "-.09", "Jul": "-.07", "Aug": "-.20", "Sep": "-.23", "Oct": "-.25", "Nov": "-.33", "Dec": "-.28", "J-D": "-.10", "D-N": "-.08", "DJF": ".02", "MAM": ".06", "JJA": "-.12", "SON": "-.27"}, {"Year": "1890", "Jan": "-.41", "Feb": "-.44", "Mar": "-.39", "Apr": "-.29", "May": "-.38", "Jun": "-.24", "Jul": "-.27", "Aug": "-.38", "Sep": "-.36", "Oct": "-.24", "Nov": "-.43", "Dec": "-.30", "J-D": "-.34", "D-N": "-.34", "DJF": "-.38", "MAM": "-.35", "JJA": "-.30", "SON": "-.34"}, {"Year": "1891", "Jan": "-.33", "Feb": "-.46", "Mar": "-.18", "Apr": "-.27", "May": "-.16", "Jun": "-.20", "Jul": "-.17", "Aug": "-.17", "Sep": "-.15", "Oct": "-.21", "Nov": "-.31", "Dec": "-.04", "J-D": "-.22", "D-N": "-.24", "DJF": "-.37", "MAM": "-.20", "JJA": "-.18", "SON": "-.22"}, {"Year": "1892", "Jan": "-.28", "Feb": "-.10", "Mar": "-.40", "Apr": "-.33", "May": "-.23", "Jun": "-.22", "Jul": "-.31", "Aug": "-.27", "Sep": "-.16", "Oct": "-.14", "Nov": "-.41", "Dec": "-.38", "J-D": "-.27", "D-N": "-.24", "DJF": "-.14", "MAM": "-.32", "JJA": "-.27", "SON": "-.24"}]'

# %% [markdown]
# # Exercise 2: functions with data

# %%
def convertion (data, function):
    
    list_output= [function(i) for i in data]
    return list_output

# %%
convertion([1,2,3,4], lambda x: x**2)
# Out:
# [1, 4, 9, 16]

# %%
def improved_convention (data, *function):
    list_output = []
    for fn in function:
        list_output.append([fn(i) for i in data])
    return list_output

# %%
improved_convention([1,2,3,4], lambda x : x**2, lambda y: y**3)
# Out:
# [[1, 4, 9, 16], [1, 8, 27, 64]]

# %%
def improved_convention_v2 (data, *function):
    return [[fn(i) for i in data] for fn in function]

# %%
improved_convention_v2([1,2,3,4], lambda x : x**2, lambda y: y**3)
# Out:
# [[1, 4, 9, 16], [1, 8, 27, 64]]

# %% [markdown]
# # Exercise 3: refactoring other people's code

# %%
""" 
This is a crawler program using beautifulsoup.
It crawls the website "https://sport050.nl/sportaanbieders/alle-aanbieders/"
and fetches all the sport suppliers in the city of Groningen. It outputs 
a csv-file with the url;phone-number;email-address of all the suppliers it can find.
"""

import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup
import ssl
import re


def hack_ssl():
    """ ignores the certificate errors"""
    ctx = ssl.create_default_context()
    ctx.check_hostname = False
    ctx.verify_mode = ssl.CERT_NONE
    return ctx


def open_url(url):
    """ reads url file as a big string and cleans the html file to make it
        more readable. input: url, output: soup object
    """
    ctx = hack_ssl()
    html = urllib.request.urlopen(url, context=ctx).read()
    soup = BeautifulSoup(html, 'html.parser')
    return soup


def read_hrefs(soup):
    """ get from soup object a list of anchor tags,
        get the href keys and and prints them. Input: soup object
    """
    reflist = []
    tags = soup('a')
    for tag in tags:
        reflist.append(tag)
    return reflist

def read_li(soup):
    lilist = []
    tags = soup('li')
    for tag in tags:
        lilist.append(tag)
    return lilist

def get_phone(info):
    reg = r"(?:(?:00|\+)?[0-9]{4})?(?:[ .-][0-9]{3}){1,5}"
    phone = [s for s in filter(lambda x: 'Telefoon' in str(x), info)]
    try:
        phone = str(phone[0])
    except:
        phone = [s for s in filter(lambda x: re.findall(reg, str(x)), info)]
        try:
            phone = str(phone[0])
        except:
            phone = ""   
    return phone.replace('Facebook', '').replace('Telefoon:', '')

def get_email(soup):
    try: 
        email = [s for s in filter(lambda x: '@' in str(x), soup)]
        email = str(email[0])[4:-5]
        bs = BeautifulSoup(email, features="html.parser")
        email = bs.find('a').attrs['href'].replace('mailto:', '')
    except:
        email = ""
    return email

def remove_html_tags(text):
    """Remove html tags from a string"""
    clean = re.compile('<.*?>')
    return re.sub(clean, '', text)

def fetch_sidebar(soup):
    """ reads html file as a big string and cleans the html file to make it
        more readable. input: html, output: tables
    """
    sidebar = soup.findAll(attrs={'class': 'sidebar'})
    return sidebar[0]

def extract(url):
    text = str(url)
    text = text[26:].split('"')[0] + "/"
    return text


# print ('fetch urls')
# url = "https://sport050.nl/sportaanbieders/alle-aanbieders/"
# s = open_url(url)
# reflist = read_hrefs(s)

# print ('getting sub-urls')
# sub_urls = [s for s in filter(lambda x: '<a href="/sportaanbieders' in str(x), reflist)]
# sub_urls = sub_urls[3:]

# print ('extracting the data')
# print (f'{len(sub_urls)} sub-urls')

# for sub in sub_urls:
#     try:
#         sub = extract(sub)
#         site = url[:-16] + sub
#         soup = open_url(site)    
#         info = fetch_sidebar(soup)
#         info = read_li(info)
#         phone = get_phone(info)
#         phone = remove_html_tags(phone).strip()
#         email = get_email(info)
#         email = remove_html_tags(email).replace("/","")
#         print (f'{site} ; {phone} ; {email}')
#     except Exception as e:
#         print (e)
#         exit()
# Out:
# fetch urls
# getting sub-urls
# extracting the data
# 415 sub-urls
# https://sport050.nl/sportaanbieders/3x3-unites/ ; 06-23929416 ; a.einolhagh@live.nl
# https://sport050.nl/sportaanbieders/40up-fitness/ ; 06-81484254 ; info@40upfitness.nl
# https://sport050.nl/sportaanbieders/5ersport/ ;  ; 5ersporten@gmail.com?subject=Bericht%20via%20Sport050.nl%20
# https://sport050.nl/sportaanbieders/s-exstudiantes/ ;  ;
# https://sport050.nl/sportaanbieders/agsr-gyas/ ; + 050 526 7445 ;
# https://sport050.nl/sportaanbieders/aihato/ ; 06-40559702 ; info@aihato.nl
# https://sport050.nl/sportaanbieders/atc75/ ;  ;
# https://sport050.nl/sportaanbieders/active-movement/ ;  ; http:info@activemovement.nl
# https://sport050.nl/sportaanbieders/adonis-sportacrobatiek/ ;  ; bestuuradonissportacrobatiek@gmail.com
# https://sport050.nl/sportaanbieders/akwaak/ ;  ;
# https://sport050.nl/sportaanbieders/allround-crossfit-groningen/ ;  ; info@allroundcrossfit.nl
# https://sport050.nl/sportaanbieders/Alumni-Sportclub-Exstudiantes/ ;  ;
# https://sport050.nl/sportaanbieders/amicitia-vmc/ ;  ;
# https://sport050.nl/sportaanbieders/art-fighting-gym/ ;  ;
# https://sport050.nl/sportaanbieders/ashtanga-yoga-groningen/ ;  ; ashtangayogagroningen@gmail.com
# https://sport050.nl/sportaanbieders/auti-taekwon-do/ ;  ;
# https://sport050.nl/sportaanbieders/bc-go/ ;  ;
# https://sport050.nl/sportaanbieders/booz-itf-taekwon-do/ ;  ; info@booz-itf-taekwondo.nl
# https://sport050.nl/sportaanbieders/bsc-caribe/ ;  ; ledenadministratie@caribe.nl
# https://sport050.nl/sportaanbieders/bv-novum/ ;  ; mail@bvnovum.nl
# https://sport050.nl/sportaanbieders/bc-beijum/ ; 06 28096707 ;
# https://sport050.nl/sportaanbieders/badminton-club-hoogkerk/ ; 06 51879000 ; bchoogkerk@gmail.com
# https://sport050.nl/sportaanbieders/badmintonclub-de-slagvink/ ;  ;
# https://sport050.nl/sportaanbieders/badmintonclub-lewenborg/ ;  ;
# https://sport050.nl/sportaanbieders/baguala-gym/ ;  ; teambaguala@outlook.com
# https://sport050.nl/sportaanbieders/balletschool-battu/ ; 050-5492919 ;
# https://sport050.nl/sportaanbieders/ballie-groningen/ ;  ; info@ballienederland.nl
# https://sport050.nl/sportaanbieders/basketbal-vereniging-groningen/ ;  ;
# https://sport050.nl/sportaanbieders/basketball-academy-rtc-noord/ ; 06-30057325 ;
# https://sport050.nl/sportaanbieders/basketbalvereniging-scylla/ ;  ;
# https://sport050.nl/sportaanbieders/be-quick-1887/ ; 050-5344950 ; hoofdopleiding@bequick1887.nl
# https://sport050.nl/sportaanbieders/beach-volley-club-groningen/ ; 06 48444574 ;
# https://sport050.nl/sportaanbieders/beachsport-groningen/ ; 06-25098894 ; secretarisbsg@gmail.com
# https://sport050.nl/sportaanbieders/betterstronger/ ;  ; info@betterstronger.nl
# https://sport050.nl/sportaanbieders/bewegen-met-marieke/ ;  ; mariekebuitenweg@gmail.com
# https://sport050.nl/sportaanbieders/bikepark-groningen/ ;  ;  info@bikepark.nl
# https://sport050.nl/sportaanbieders/biljartcentrum-1977/ ;  ; http:penningmeester@biljartcentrum1977.nl
# https://sport050.nl/sportaanbieders/biljartclub-de-harmonie/ ; 050-3129717 ;
# https://sport050.nl/sportaanbieders/bodyfitharen/ ;  ; info@bodyfitharen.nl
# https://sport050.nl/sportaanbieders/boksvereniging-abelsma/ ;  ;
# https://sport050.nl/sportaanbieders/bootcamp-050/ ;  ;
# https://sport050.nl/sportaanbieders/bootcamp-noord/ ;  ;
# https://sport050.nl/sportaanbieders/boxing-stad-groningen/ ;  ; info@boxingstadgroningen.nl
# https://sport050.nl/sportaanbieders/boxing-team-alshawa/ ; 06-23841451 ; http:Info@boxing-team-alshawa.nl
# https://sport050.nl/sportaanbieders/breakout-grunopark/ ;  ;
# https://sport050.nl/sportaanbieders/bslim/ ;  ;
# https://sport050.nl/sportaanbieders/ckv-rog/ ;  ; ws@rog-korfbal.nl
# https://sport050.nl/sportaanbieders/czc-de-springplank/ ;  ; despringplank1961@gmail.com
# https://sport050.nl/sportaanbieders/csv-voorwaarts-haren/ ;  ; secr@voorwaartsharen.nl
# https://sport050.nl/sportaanbieders/czv-de-dolfijn/ ;  ; info@czvdedolfijn.nl
# https://sport050.nl/sportaanbieders/calipso-fit-studio/ ;  ; info@calipsofitstudio.com
# https://sport050.nl/sportaanbieders/calamity-volleybal/ ;  ;
# https://sport050.nl/sportaanbieders/caliclub/ ;  ; hallo@caliclub.nl
# https://sport050.nl/sportaanbieders/celeritas-donar/ ; 0503127832 ;
# https://sport050.nl/sportaanbieders/chair-workout/ ;  ; info@chairworkout.net
# https://sport050.nl/sportaanbieders/chungmukwan-hankido-groningen/ ;  ; sport050@hankidogroningen.nl
# https://sport050.nl/sportaanbieders/circus-santelli/ ;  ; info@santelli.nl
# https://sport050.nl/sportaanbieders/club-brothers/ ; 0599-235770 ;
# https://sport050.nl/sportaanbieders/colosseum/ ;  ; info@colosseum.nl
# https://sport050.nl/sportaanbieders/connorsports/ ;  ; info@connorsports.nl
# https://sport050.nl/sportaanbieders/creative-fighting-arts-systema-groningen/ ; 06 17805091 ; info@systema-groningen.nl
# https://sport050.nl/sportaanbieders/crossfit-noord/ ;  ; info.cfnoord@gmail.com
# https://sport050.nl/sportaanbieders/curves-groningen/ ;  ; groningen@curves.nl
# https://sport050.nl/sportaanbieders/curves-groningen-centrum/ ;  ; groningencentrum@curves.nl
# https://sport050.nl/sportaanbieders/cycle-sport-groningen/ ;  ;
# https://sport050.nl/sportaanbieders/cycling-espresso/ ;  ;
# https://sport050.nl/sportaanbieders/dws-zvv-oosterpoort/ ;  ;
# https://sport050.nl/sportaanbieders/dzn-groningen/ ; dznnieuws@gmail.com ; dznnieuws@gmail.com
# https://sport050.nl/sportaanbieders/dansschool-dance-dali/ ; 06-30880636 ; ilona@dance-dali.nl
# https://sport050.nl/sportaanbieders/de-beweegservice/ ;  ; info@debeweegservice.nl
# https://sport050.nl/sportaanbieders/de-brug-regio-stad-groningen/ ;  ;
# https://sport050.nl/sportaanbieders/de-watergeuzen/ ;  ; info@duikteamdewatergeuzen.nl
# https://sport050.nl/sportaanbieders/de-watervrienden-groningen/ ;  ;
# https://sport050.nl/sportaanbieders/dijkmansport-groningen/ ; 050 311 38 51 ;
# https://sport050.nl/sportaanbieders/dio-groningen/ ; 0623192982 ;
# https://sport050.nl/sportaanbieders/disc-golf-noord-nederland/ ; www.discgolfnoordnederland.nl ; info@discgolfnoordnederland.nl
# https://sport050.nl/sportaanbieders/diva83/ ;  ;
# https://sport050.nl/sportaanbieders/dojo-kokoro/ ;  ; dojo@dojokokoro.nl
# https://sport050.nl/sportaanbieders/donar/ ;  ;
# https://sport050.nl/sportaanbieders/drentse-kunstrijvereniging/ ;  ; secretarisdkv@gmail.com
# https://sport050.nl/sportaanbieders/duikvereniging-miramar/ ; 06 22649965 ; info@miramargroningen.nl
# https://sport050.nl/sportaanbieders/emd-dance-company/ ; 06 28966069 ; emddancecompany@gmail.com
# https://sport050.nl/sportaanbieders/east-end-strength-sports/ ;  ; easstendgroningen@gmail.com
# https://sport050.nl/sportaanbieders/f-en-f-inner-way/ ; 0515-432030 ; info@sportclubfenf.nl
# https://sport050.nl/sportaanbieders/fc-groningen/ ; 050 - 5 87 87 87 ; info@fcgroningen.nl
# https://sport050.nl/sportaanbieders/fc-lewenborg/ ; 050 541 9284 ;
# https://sport050.nl/sportaanbieders/fc-urban/ ; www.fcurban.nl/groningen/ ; sem@fcurban.nl
# https://sport050.nl/sportaanbieders/fd-personal-training/ ; 0618437843 ; Ptfranciscodoezeman@gmail.com
# https://sport050.nl/sportaanbieders/fi-t-rition/ ; 06-81220180 ; fitrition.company@gmail.com
# https://sport050.nl/sportaanbieders/fight-academy-groningen/ ; Telefoonnummer: 0653637875 ; Fightacademygroningen@gmail.com
# https://sport050.nl/sportaanbieders/fit-curpa/ ;  ; http:info@fitcurpa.com
# https://sport050.nl/sportaanbieders/fitleven/ ; fitlevengroningen.com ; fitlevengroningen@outlook.com
# https://sport050.nl/sportaanbieders/fitkids-groningen-noord/ ; 050-5422667 ; info@fysiotherapiedehunze.nl
# https://sport050.nl/sportaanbieders/fitstap-groningen/ ; info@mindenfit.nl ; info@mindenfit.nl
# https://sport050.nl/sportaanbieders/flexbeweging/ ; 06-30920958 ; joelvanderwoude777@gmail.com
# https://sport050.nl/sportaanbieders/footy/ ; 06-38032132 ; info@playfooty.com
# https://sport050.nl/sportaanbieders/funboxx/ ;  ; info@kitemobile.nl
# https://sport050.nl/sportaanbieders/gbdcalamari/ ;  ; onderwaterhockey@gbdcalamari.nl
# https://sport050.nl/sportaanbieders/ghlsv-goud-groningen-gaysport/ ;  ; info@goudgroningen.nl
# https://sport050.nl/sportaanbieders/gltv-cream-crackers/ ; 050 525 99 69 ;
# https://sport050.nl/sportaanbieders/gsavvforward/ ; +31652559449 ;
# https://sport050.nl/sportaanbieders/gsbv-de-matteklopppers/ ;  ;
# https://sport050.nl/sportaanbieders/gsrv-de-graancirkel/ ; 06-34268127 ; secretaris@degraancirkel.nl
# https://sport050.nl/sportaanbieders/gsvb-de-groene-uilen-moestasj/ ;  ; info@groeneuilenmoestasj.nl
# https://sport050.nl/sportaanbieders/gsvv-donitas/ ;  ; info@donitas.nl
# https://sport050.nl/sportaanbieders/gsvv-tjas/ ; 06-13562447 ;
# https://sport050.nl/sportaanbieders/gswc-bares/ ;  ;
# https://sport050.nl/sportaanbieders/gszc-de-walvisch/ ;  ;
# https://sport050.nl/sportaanbieders/gv-groen-geel/ ;  ;
# https://sport050.nl/sportaanbieders/gdvv-martinistad/ ;  ;
# https://sport050.nl/sportaanbieders/gltb/ ; 050 - 526 23 68 ;
# https://sport050.nl/sportaanbieders/go180-personal-trainers/ ; 050-2110600 ;
# https://sport050.nl/sportaanbieders/grc-groningen/ ; 050 - 52 60 649 ;
# https://sport050.nl/sportaanbieders/gsav-vitalis/ ; .com ;
# https://sport050.nl/sportaanbieders/gsbv-tweeslag/ ;  ; bestuur@tweeslag.nl
# https://sport050.nl/sportaanbieders/gsr-aegir/ ; 050-3124666 ;
# https://sport050.nl/sportaanbieders/gstv-tritanium/ ;  ;
# https://sport050.nl/sportaanbieders/gsvv-knickerbockers/ ; 06-54271617 ;
# https://sport050.nl/sportaanbieders/gswv-tandje-hoger/ ;  ;
# https://sport050.nl/sportaanbieders/gsyv-bulldogs-groningen/ ;  ;
# https://sport050.nl/sportaanbieders/gttc/ ; Telefoon 06-48072553 (kantine) ;
# https://sport050.nl/sportaanbieders/gvav-rapiditas-triathlon/ ;  ;
# https://sport050.nl/sportaanbieders/gvav-rapiditas/ ; 06-10133480 ;
# https://sport050.nl/sportaanbieders/gajja-mitts/ ;  ;
# https://sport050.nl/sportaanbieders/gehandicapten-sportclub-groningen/ ; 06 - 42 91 41 16 ;
# https://sport050.nl/sportaanbieders/gijs-groningen-ijshockey/ ;  ;
# https://sport050.nl/sportaanbieders/go-2-moves/ ;  ;
# https://sport050.nl/sportaanbieders/go-smarts/ ; 06 249 250 45 ;
# https://sport050.nl/sportaanbieders/go4harimau/ ; 050-5718144 ; info@go4harimau.nl
# https://sport050.nl/sportaanbieders/gronical-dizziness/ ;  ;
# https://sport050.nl/sportaanbieders/groningen-atletiek/ ;  ; info@groningenatletiek.nl
# https://sport050.nl/sportaanbieders/groningen-bike-polo/ ; 06 55931414 ; groningenbikepolo@gmail.com
# https://sport050.nl/sportaanbieders/groningen-cheerleading-giants/ ; Kiel Gymzaal (Kiel 9, 9733 EB Groningen) ; cheer@groningengiants.nl
# https://sport050.nl/sportaanbieders/groningen-gaels/ ; 00353872242841 ; chairperson.groningen.europe@gaa.ie
# https://sport050.nl/sportaanbieders/groningen-giants/ ;  ; bestuur@groningengiants.nl
# https://sport050.nl/sportaanbieders/groninger-combinatie/ ; 050-3110375 ;
# https://sport050.nl/sportaanbieders/groninger-handboog-vereniging-vector/ ;  ;
# https://sport050.nl/sportaanbieders/groninger-kanovereniging/ ; (050) 527 0030 ; secretaris@groningenkv.nl
# https://sport050.nl/sportaanbieders/groninger-reddingsbrigade/ ;  ; info@groningerreddingsbrigade.nl
# https://sport050.nl/sportaanbieders/groninger-studenten-rugby-club/ ;  ;
# https://sport050.nl/sportaanbieders/groninger-studenten-zeilvereniging-mayday/ ;  ; bestuur@gszmayday.nl
# https://sport050.nl/sportaanbieders/groninger-tafeltennis-club/ ; 06-48072553 ; secretaris@gttc.nl
# https://sport050.nl/sportaanbieders/gz-trivia/ ;  ; secretariaat@trivia.nl
# list index out of range
# https://sport050.nl/sportaanbieders/grupo-ginga-da-alma/ ;  ; gingadalma@gmail.com
# https://sport050.nl/sportaanbieders/gustafit/ ;  ; gustafit@outlook.com
# https://sport050.nl/sportaanbieders/gym-lounge-groningen/ ;  ; groningen@gymlounge.nl
# https://sport050.nl/sportaanbieders/gym-en-volleybalclub/ ;  ; jw.fellinga@planet.nl
# https://sport050.nl/sportaanbieders/gym-en-turnsport-ten-boer/ ;  ; info@gymenturnsport.nl
# https://sport050.nl/sportaanbieders/gymnow/ ;  ; info@gymnow.nl
# https://sport050.nl/sportaanbieders/gymzero50/ ; 06-82985011 ; gymzero50@gmail.com
# https://sport050.nl/sportaanbieders/h-s-v-basketball/ ;  ;
# https://sport050.nl/sportaanbieders/hv-de-cirkeltijgers/ ; 06 83514222 ;  bestuur@cirkeltijgers.nl
# https://sport050.nl/sportaanbieders/hfc-15/ ;  ;
# https://sport050.nl/sportaanbieders/handbalvereniging-vs-groningen/ ; 06-446 72 761 (Secretaris) ; vens@handbal.nl
# https://sport050.nl/sportaanbieders/hap-ki-do/ ; Telefoon : (050)-5414251 ;
# https://sport050.nl/sportaanbieders/hapkido-nha/ ;  ;
# https://sport050.nl/sportaanbieders/happy-body-company/ ; Telefoonnummer: 0624510059 ; lee-roy@happybody.company
# https://sport050.nl/sportaanbieders/happy-body-movement/ ; 06-24510059 ; info@happybodymovement.nl
# https://sport050.nl/sportaanbieders/hardwerk/ ;  ; info@clubhardwerk.nl
# https://sport050.nl/sportaanbieders/harener-badminton-club-68/ ;  ; harenerbc68@gmail.com
# https://sport050.nl/sportaanbieders/helmsport/ ; 06-50471216 ;
# list index out of range
# https://sport050.nl/sportaanbieders/hockeyclub-groningen/ ;  ; secretaris@ghhc.nl
# https://sport050.nl/sportaanbieders/ghbs/ ; 050-5291166 (clubhuis) ;
# https://sport050.nl/sportaanbieders/hommes-survival-outdoor/ ;  ;
# https://sport050.nl/sportaanbieders/hydrofiel-duikvereniging/ ;  ;
# https://sport050.nl/sportaanbieders/hypnofit-bootcamp/ ;  ; info@hypnofitbootcamp.nl
# https://sport050.nl/sportaanbieders/ijsvereniging-borgercompagnie/ ;  ;
# https://sport050.nl/sportaanbieders/ijsvereniging-groningen/ ;  ; bestuur@yvg.nl
# https://sport050.nl/sportaanbieders/indoor-sports-centre/ ;  ; info@indoorsportscentre.nl
# https://sport050.nl/sportaanbieders/indoorgroep-haren/ ;  ; boeremajaap@gmail.com
# https://sport050.nl/sportaanbieders/indoorstrand-binnnpret-bv/ ;  ;
# https://sport050.nl/sportaanbieders/inez-schuitema/ ;  ;
# https://sport050.nl/sportaanbieders/inline-sport/ ; 06-34064747 ; info@inline-sport.nl
# https://sport050.nl/sportaanbieders/innerkick/ ;  ; info@innerkick.nl
# https://sport050.nl/sportaanbieders/italian-boys/ ;  ;
# https://sport050.nl/sportaanbieders/jsc-de-matadoren/ ; Website ; superhiddo@hetnet.nl
# https://sport050.nl/sportaanbieders/jeanette-toxopeus/ ;  ; j.tox@ziggo.nl
# https://sport050.nl/sportaanbieders/jerrys-gym/ ;  ; info@jerrysgym.nl
# https://sport050.nl/sportaanbieders/jiritsu/ ; 06-49965849 ;
# https://sport050.nl/sportaanbieders/jodo-groningen/ ; 06-25577739 ; http:info@jodo-groningen.nl
# https://sport050.nl/sportaanbieders/judo-academy-noord-nederland/ ;  ; info@judoacademy-nn.nl
# https://sport050.nl/sportaanbieders/judo-vereniging-bakker/ ;  ;
# https://sport050.nl/sportaanbieders/judoschool-renshu/ ;  ; info@renshu.nl
# https://sport050.nl/sportaanbieders/kv-hoogkerk/ ;  ;
# https://sport050.nl/sportaanbieders/kv-wezon-de-sterke-earm/ ;  ; wezon@live.nl
# https://sport050.nl/sportaanbieders/k4groningen/ ;  ; k4groningen@gmail.com
# https://sport050.nl/sportaanbieders/kanosportvereniging-forward/ ; 06-19558289 ; info@ksvforward.nl
# https://sport050.nl/sportaanbieders/karate-dojo-scharlakenhof/ ; 06-40785149 ; janvto@gmail.com
# https://sport050.nl/sportaanbieders/karate-voor-volwassenen/ ;  ; eahoeksma@ziggo.nl
# https://sport050.nl/sportaanbieders/karatevereniging-za-kura/ ; 050-3061707 ; info@zakura.nl
# https://sport050.nl/sportaanbieders/kazemi-taekwondo-academie/ ;  ; kazemitaekwondo@gmail.com
# https://sport050.nl/sportaanbieders/keepersschool-groningen/ ;  ; info@keepingthezero.nl
# https://sport050.nl/sportaanbieders/kendovereniging-shin-bu-kan/ ;  ; willem@wilbo.demon.nl
# https://sport050.nl/sportaanbieders/kickboxing-harkstede/ ;  ; rvancalker01@home.nl
# https://sport050.nl/sportaanbieders/kids-united/ ; 050-5427040 ;
# https://sport050.nl/sportaanbieders/kinesica/ ;  ; xander.barel@gmail.com
# https://sport050.nl/sportaanbieders/kitemobile/ ;  ; info@kitemobile.nl
# https://sport050.nl/sportaanbieders/klimcentrum-bjoeks/ ; 050 549 1230 ; info@bjoeks.nl
# https://sport050.nl/sportaanbieders/kgr-de-hunze/ ;  ; info@hunze.nl
# https://sport050.nl/sportaanbieders/korfbalvereniging-nic/ ; 0629166237 ;
# https://sport050.nl/sportaanbieders/kriya/ ;  ; kriyamovement@gmail.com
# https://sport050.nl/sportaanbieders/kroton-volleybal-vereniging/ ;  ;
# https://sport050.nl/sportaanbieders/kung-fu-wushu-vereniging-bao-trieu-blijd/ ; 06 21 811 216 ; info@baotrieu.com
# https://sport050.nl/sportaanbieders/kunstrijclub-groningen-kcg/ ;  ; info@kunstrijclubgroningen.nl
# https://sport050.nl/sportaanbieders/kurokumo-bushido-academy/ ;  ; kurokumobushidoacademie@gmail.com
# https://sport050.nl/sportaanbieders/kwon-moo/ ; 050-5415824 ;
# https://sport050.nl/sportaanbieders/la-danse/ ;  ;
# https://sport050.nl/sportaanbieders/lacrosse-groningen-gladiators/ ; 06-45367278 ; info@lacrossegroningen.nl
# https://sport050.nl/sportaanbieders/leefstijl050/ ;  ; info@leefstijl050.nl
# https://sport050.nl/sportaanbieders/life-beat/ ; 06 23376388 ; info@life-beat.nl
# https://sport050.nl/sportaanbieders/loopgroep-astrea/ ;  ;
# https://sport050.nl/sportaanbieders/loopgroep-groningen/ ;  ; secretaris@loopgroepgroningen.nl
# https://sport050.nl/sportaanbieders/loopgroep-grunn/ ; 06-22564473 ; info@loopgroepgrunn.nl
# https://sport050.nl/sportaanbieders/loopplezier/ ;  ; info@loopplezier.nl
# https://sport050.nl/sportaanbieders/louisa-martial-arts/ ;  ;
# https://sport050.nl/sportaanbieders/lycurgus-volleybal-vereniging/ ;  ;
# https://sport050.nl/sportaanbieders/mars-vechtschool-voor-middeleeuwse-krijgskunsten-noord-nederland/ ; Telefoonnummer: +31633748759 ; info@mars-swordfighting.com
# https://sport050.nl/sportaanbieders/mars-vechtschool/ ;  ; info@mars-swordfighting.com
# https://sport050.nl/sportaanbieders/mygym-groningen/ ;  ; info@mygymgroningen.nl
# https://sport050.nl/sportaanbieders/madjoe-zvv/ ; www.facebook.com ;
# https://sport050.nl/sportaanbieders/maple-leaf/ ; 050-5262088 ;
# https://sport050.nl/sportaanbieders/marfitt/ ;  ;
# https://sport050.nl/sportaanbieders/martini-moose/ ; 06-21860455 ; martin-brink@outlook.com
# https://sport050.nl/sportaanbieders/martini-sparks/ ;  ; secretaris@martinisparks.nl
# https://sport050.nl/sportaanbieders/martinistad-lacrosse/ ;  ; info@martinistadlacrosse.nl
# https://sport050.nl/sportaanbieders/medisupport/ ; 050-3182164 ;
# https://sport050.nl/sportaanbieders/mijn-zwemschool-groningen/ ;  ;
# https://sport050.nl/sportaanbieders/mischa-top/ ;  ;
# https://sport050.nl/sportaanbieders/misheru-chikara-gym/ ;  ;
# https://sport050.nl/sportaanbieders/mojo/ ; 050-7851720 ; mojo@eilandvangroningen.com
# https://sport050.nl/sportaanbieders/mom-balance-groningen/ ;  ;
# https://sport050.nl/sportaanbieders/monkey-moves/ ; 06-40597028 ; groningen@monkeymoves.nl
# https://sport050.nl/sportaanbieders/move4progress/ ;  ; info@move4progress.nl
# https://sport050.nl/sportaanbieders/movement-center/ ; 06-53502251 ; contact@schoolfreerun.nl
# https://sport050.nl/sportaanbieders/movement-instinct/ ; 06-48517251 ; info@movementinstinct.nl
# https://sport050.nl/sportaanbieders/nzg/ ;  ;
# https://sport050.nl/sportaanbieders/naturisten-zwemvereniging-groningen/ ;  ;
# https://sport050.nl/sportaanbieders/niets-om-t-lijf/ ; +31-(0)6-46025592 ;
# https://sport050.nl/sportaanbieders/no-clouds-today/ ; 06-52786228 ; info@nocloudstoday.com
# https://sport050.nl/sportaanbieders/noordelijke-wieler-vereniging/ ;  ;
# https://sport050.nl/sportaanbieders/ozw/ ; 050-454 565 ; ozw1934@hotmail.nl
# https://sport050.nl/sportaanbieders/open-yoga/ ;  ; info@openyoga.nl
# list index out of range
# https://sport050.nl/sportaanbieders/oranje-nassau-volleybalvereniging/ ;  ;
# https://sport050.nl/sportaanbieders/oranje-nassau-cvv/ ;  ;
# https://sport050.nl/sportaanbieders/power-methode/ ; 06-45541001 ; info@power-methode.nl
# https://sport050.nl/sportaanbieders/paulo-boer-personal-training/ ; Griffeweg 7, 9724GE Groningen ; info@pauloboer.nl
# https://sport050.nl/sportaanbieders/peakz-padel/ ;  ; euroborg@playpadel.nl
# https://sport050.nl/sportaanbieders/personal-body-shape/ ;  ; info@personalbodyshape.nl
# https://sport050.nl/sportaanbieders/personal-fit-noord/ ; 06-57660817 ;
# https://sport050.nl/sportaanbieders/personal-training-noord/ ;  ;
# https://sport050.nl/sportaanbieders/petersport/ ; 06-51688424 ; pjpettinga@hotmail.com
# https://sport050.nl/sportaanbieders/petra-de-groot/ ; 0642417759 ; contact@petradegroot.com
# https://sport050.nl/sportaanbieders/pilates-groningen-studio-nora-knol/ ; 06-20163298 ; info@pilatesgroningen.nl
# https://sport050.nl/sportaanbieders/plaza-sportiva/ ; OV binnen 200 mtr. ; welkom@plazasportiva.nl
# https://sport050.nl/sportaanbieders/powerwalking-club-groningen/ ;  ; r_deiman@hotmail.com
# https://sport050.nl/sportaanbieders/powerwalkingclub-groningen-mindfit/ ;  ; info@powerwalkinggroningen.nl
# https://sport050.nl/sportaanbieders/presto-garmerwolde/ ; 06-1070723 ; info@ijsverenigingpresto.nl
# https://sport050.nl/sportaanbieders/pres-le/ ; 06-46013288 ; http:secretariaat@preslebut.nl
# https://sport050.nl/sportaanbieders/push-pull-fitness/ ; 050-3646372 ; info@pushenpull.nl
# https://sport050.nl/sportaanbieders/rtc-waterpolo/ ;  ; groningen@rtcwaterpolo.nl
# https://sport050.nl/sportaanbieders/rame-dance-club/ ;  ;
# https://sport050.nl/sportaanbieders/renate-hensen/ ;  ; renate@improveyourmind.nl
# https://sport050.nl/sportaanbieders/renshu-fights/ ;  ; info@renshu-fights.nl
# https://sport050.nl/sportaanbieders/robert-terpstra/ ;  ;  k.r.a.terpstra@home.nl
# https://sport050.nl/sportaanbieders/roller-derby-groningen/ ;  ; info@rollerderbygroningen.nl
# https://sport050.nl/sportaanbieders/root-mma/ ; 06-39806688 ; info@rootmma.nl
# https://sport050.nl/sportaanbieders/rugby-club-groningen/ ; 050 75 21 211 ;
# https://sport050.nl/sportaanbieders/sm-sports-and-movement/ ;  ; info@sportsandmovement.nl
# https://sport050.nl/sportaanbieders/ssv-martini/ ; 050-5269740 (alleen op maandag van 19:30 tot 22:00) ; info@svmartini.nl
# https://sport050.nl/sportaanbieders/strs-personal-training/ ;  ; info@starspt.nl
# https://sport050.nl/sportaanbieders/sv-athene/ ; 050-5416743 ; sonja.thie@home.nl
# https://sport050.nl/sportaanbieders/swnl-groningen/ ;  ; swnl@hotmail.com
# https://sport050.nl/sportaanbieders/sjo-coendersborg/ ;  ; secretaris@sjocoendersborg.nl
# https://sport050.nl/sportaanbieders/sjok/ ;  ; info@sjok.nl
# https://sport050.nl/sportaanbieders/ssv-rabenhaupt/ ; 06-46342426 (S. Veldthuis, Voorzitter) ; secretaris@rabenhaupt.nl
# https://sport050.nl/sportaanbieders/stv-eemsmond/ ;  ; stveemsmond@gmail.com
# https://sport050.nl/sportaanbieders/sv-dio/ ;  ; info@diosport.nl
# https://sport050.nl/sportaanbieders/sv-groningen/ ; 050-5269740 ;
# https://sport050.nl/sportaanbieders/sv-lycurgus/ ; 06 - 519 88 246 ;
# https://sport050.nl/sportaanbieders/sv-scharlakenhof/ ;  ;
# https://sport050.nl/sportaanbieders/sv-teo/ ; 050-3021861 ;
# https://sport050.nl/sportaanbieders/sv-vlugheid-en-kracht/ ; 050 - 541 42 08 ; info@vlugheidenkracht.nl
# https://sport050.nl/sportaanbieders/sv-woltersum/ ;  ;
# https://sport050.nl/sportaanbieders/svv-helpman/ ;  ;
# https://sport050.nl/sportaanbieders/sadasiva/ ; 06 16012860 ; info@sadasiva.nl
# https://sport050.nl/sportaanbieders/sami-johnson/ ;  ; sami.johnson660@gmail.com
# https://sport050.nl/sportaanbieders/sapphiresephora-dance-class/ ;  ; sapphiresephora@hotmail.com
# https://sport050.nl/sportaanbieders/satyayoga/ ;  ; info@satyayoga.nl
# https://sport050.nl/sportaanbieders/schaakclub-haren/ ;  ; jeugdleider@schaakclubharen.nl
# https://sport050.nl/sportaanbieders/schaatsclub-de-ijsvogels/ ; 0512-342533 ; wheida@hotmail.com
# https://sport050.nl/sportaanbieders/schaatsgroep-de-polderputten/ ;  ; http:schaatsgroep@polderputten.nl
# https://sport050.nl/sportaanbieders/schaatsvereniging-hardrijdersvereniging-oost-groningen/ ;  ;
# https://sport050.nl/sportaanbieders/schaatsvereniging-de-hunen/ ;  ; info@schaatsvereniging-de-hunen.nl
# https://sport050.nl/sportaanbieders/schaatsvereniging-de-stayer/ ;  ; info@destayer.nl
# https://sport050.nl/sportaanbieders/schaatsvereniging-noordoost-drenthe/ ; 06-12781774 ; secretaris@svnoordoostdrenthe.nl
# https://sport050.nl/sportaanbieders/schaatsvereniging-scharlakenhof/ ;  ; http:voorzitter@svscharlakenhof.nl
# https://sport050.nl/sportaanbieders/schaatsvereniging-de-scheuvelloper/ ;  ; http:info@scheuvelloper.nl
# https://sport050.nl/sportaanbieders/scheidsrechtersvereniging-groningen-eo/ ;  ; covsgroningen@gmail.com
# https://sport050.nl/sportaanbieders/schermcentrum-noord/ ; +31 (0)651518137 ; schermcentrumnoord@hotmail.com
# https://sport050.nl/sportaanbieders/schermvereniging-heerenleed/ ; 06-330 80 144 ; voorzitter@schermverenigingheerenleed.nl
# https://sport050.nl/sportaanbieders/school-taiji-groningen/ ; 0594-515678 ; schooloftaijigroningen@gmail.com
# https://sport050.nl/sportaanbieders/sean-van-der-wiel-fysiotherapie-en-personal-training/ ;  ; fysiostadgroningen@gmail.com
# https://sport050.nl/sportaanbieders/self-defense-academy/ ;  ; robert@selfdefense-academy.nl
# https://sport050.nl/sportaanbieders/sergeij-barthelt/ ;  ;
# https://sport050.nl/sportaanbieders/shorttrack-groningen/ ;  ; http:shorttrack.groningen@gmail.com
# https://sport050.nl/sportaanbieders/shotokan-karate-noord-nederland/ ;  ; info@shotokankaratenoordnederland.nl
# https://sport050.nl/sportaanbieders/simply-bmx/ ;  ;
# https://sport050.nl/sportaanbieders/slim-leven-vinkhuizen/ ;  ; slimleven@wij.groningen.nl
# https://sport050.nl/sportaanbieders/sloeproeiers-groningen/ ; 06-13127149 ; bestuur@sloeproeiers.nl
# https://sport050.nl/sportaanbieders/smash-block-volleybal-vereniging/ ;  ; smashandblocktc@gmail.com
# https://sport050.nl/sportaanbieders/smashing/ ;  ;
# https://sport050.nl/sportaanbieders/snooker-academie-groningen/ ;  ;
# https://sport050.nl/sportaanbieders/snookervereniging-groningen/ ;  ; info@snookergroningen.nl
# https://sport050.nl/sportaanbieders/snowlimits-ski-outdoorcentrum/ ; 050 - 5892039 ; info@snowlimits.nl
# https://sport050.nl/sportaanbieders/sound-of-walking/ ; 050-3140490 ; http:m.a.osse@home.nl
# https://sport050.nl/sportaanbieders/sportcenter-arobus/ ; 050 302 3080 ; http:info@arobus.nl
# https://sport050.nl/sportaanbieders/sportcenter-wijnand-tapilatu/ ; 050 - 556 72 98 ; w_tapilatu@hotmail.com
# https://sport050.nl/sportaanbieders/sportcentrum-balili/ ;  ; info@sportcentrumbalili.nl
# https://sport050.nl/sportaanbieders/sportcentrum-kardinge/ ; 050 3676767 (optie 1) ;
# https://sport050.nl/sportaanbieders/sportclub-groningen/ ;  ; info@sportclubgroningen.nl
# https://sport050.nl/sportaanbieders/sportclub-hoogkerk/ ; 06 23281606 ; jurjenellen@hotmail.com
# https://sport050.nl/sportaanbieders/sportclub-de-deurdouwers/ ;  ; j.u.koopman@home.nl
# https://sport050.nl/sportaanbieders/sportfit-noord/ ;  ;
# https://sport050.nl/sportaanbieders/sportief-90/ ; 050-3185639 ; info@sportief90.nl
# https://sport050.nl/sportaanbieders/sportlab-groningen/ ;  ; stefan@sportlabgroningen.nl
# https://sport050.nl/sportaanbieders/sportvereniging-vlugheid-en-kracht/ ; 050 - 541 42 08 ;
# https://sport050.nl/sportaanbieders/springs-sport-dance-club/ ; 050-3182333 ; info@springs.nl
# https://sport050.nl/sportaanbieders/ssang-su-kwan-zwaardvechten/ ;  ;
# https://sport050.nl/sportaanbieders/stadsparklopers/ ;  ;
# https://sport050.nl/sportaanbieders/steenbok-sport/ ; 06-22564473 ; jan@steenboksport.nl
# https://sport050.nl/sportaanbieders/stichting-40mijl/ ; 085 2016 534 ; info@40mijl.nl
# https://sport050.nl/sportaanbieders/stichting-bea/ ; 050-3610907 ; sportcomplex@umcg.nl
# https://sport050.nl/sportaanbieders/stichting-schietbanen-groningen/ ;  ;
# https://sport050.nl/sportaanbieders/stichting-shera-fight/ ;  ; info@sherafight.nl
# https://sport050.nl/sportaanbieders/stichting-tang-su/ ;  ;
# https://sport050.nl/sportaanbieders/studenten-turngroep-groningen/ ;  ; bestuur@stuggmail.nl
# https://sport050.nl/sportaanbieders/sung-zang/ ; 06-11476113 ;
# https://sport050.nl/sportaanbieders/tc-veracket/ ; 06-16699037 ;
# https://sport050.nl/sportaanbieders/tc-ten-boer/ ;  ; secretariaat@tctb.nl
# https://sport050.nl/sportaanbieders/tsh-haren/ ;  ;
# https://sport050.nl/sportaanbieders/ttv-vinkhuizen/ ; 050-5263602 ;
# https://sport050.nl/sportaanbieders/taekwondo-club-noord/ ;  ; info@taekwondoclubnoord.nl
# https://sport050.nl/sportaanbieders/taekwondoschool-henk-meijer/ ; +31 6 54 23 21 67 ;
# https://sport050.nl/sportaanbieders/team-abc-achieve-body-control/ ;  ; achievebodycontrol@gmail.com
# https://sport050.nl/sportaanbieders/tennisclub-albertus-magnus/ ;  ; praeses@tam.nl
# https://sport050.nl/sportaanbieders/tennisvereniging-glimmen/ ;  ; secretaris@tvglimmen.nl
# https://sport050.nl/sportaanbieders/gym-haren/ ;  ;
# https://sport050.nl/sportaanbieders/tomoveyou/ ;  ; info@tomoveyou.nl
# https://sport050.nl/sportaanbieders/tommyfit/ ;  ; info.tommyfit@gmail.com
# https://sport050.nl/sportaanbieders/totally-shape/ ; 050-8505999 ;
# https://sport050.nl/sportaanbieders/training-movement/ ;  ; info@trainingandmovement.nl
# https://sport050.nl/sportaanbieders/training-teaching/ ; 06-20538612 ; info@trainingenteaching.nl
# https://sport050.nl/sportaanbieders/turnstad-groningen/ ; 06-36292324 ; verenigingsmanager@turnstadgroningen.nl
# https://sport050.nl/sportaanbieders/unihockey-floorball-club-groningen/ ;  ; info@ufcgroningen.nl
# https://sport050.nl/sportaanbieders/vv-mamio/ ; 06-15272275 (wedstrijdsecretaris) ; info@vvmamio.nl
# https://sport050.nl/sportaanbieders/vv-helpman/ ; 050-5256027 ; info@vvhelpman.nl
# https://sport050.nl/sportaanbieders/vv-engelbert/ ;  ;
# https://sport050.nl/sportaanbieders/vv-geo/ ; 050-5413108 ; info@vvgeo.nl
# https://sport050.nl/sportaanbieders/vv-glimmen/ ;  ;
# https://sport050.nl/sportaanbieders/vv-gorecht/ ;  ; secretaris@vvgorecht.nl
# https://sport050.nl/sportaanbieders/vv-gruno/ ; 06-83600355 ;
# https://sport050.nl/sportaanbieders/vv-haren/ ;  ;
# https://sport050.nl/sportaanbieders/vv-omlandia/ ; 050-3021837 ; secretaris@vvomlandia.nl
# https://sport050.nl/sportaanbieders/vvk-groningen/ ;  ; info@vvkgroningen.nl
# https://sport050.nl/sportaanbieders/vwdtp-vereniging-watersport-de-twee-provincien/ ;  ; pr@vwdtp.nl
# https://sport050.nl/sportaanbieders/velocitas-1897/ ; 050-5263099 (bestuurskamer) ;
# https://sport050.nl/sportaanbieders/veracles/ ; 06 - 28872344 ;
# https://sport050.nl/sportaanbieders/vida/ ;  ;
# https://sport050.nl/sportaanbieders/voetbaltennismasters/ ;  ; voetbaltennismasters@gmail.com
# https://sport050.nl/sportaanbieders/voetbalcenter-meerstad/ ; 06-53447915 ; rene@voetbalcenter-meerstad.nl
# https://sport050.nl/sportaanbieders/voetbalschool-bequick-1887/ ;  ; vbs1887@gmail.com
# https://sport050.nl/sportaanbieders/voetbalvereniging-pkc83/ ; 050-5253847 ;
# https://sport050.nl/sportaanbieders/voetjebal-groningen/ ; 06-13402403 ; groningen@voetjebal.com
# https://sport050.nl/sportaanbieders/volleybal-vereniging-menhir/ ;  ;
# https://sport050.nl/sportaanbieders/oryx-volleybal-vereniging/ ;  ; bestuur@vvoryx.nl
# https://sport050.nl/sportaanbieders/volleybalclub-young-ones/ ;  ; harryschuringa@hotmail.com
# https://sport050.nl/sportaanbieders/volleybalvereniging-apsaz/ ;  ; bestuur@apsaz.nl
# https://sport050.nl/sportaanbieders/volleybalvereniging-dgb-groningen/ ; 0651900066 ;
# https://sport050.nl/sportaanbieders/volleybalvereniging-olympia/ ;  ;
# https://sport050.nl/sportaanbieders/volleybalvereniging-oosterpoort/ ;  ;
# https://sport050.nl/sportaanbieders/volleybalvereniging-overspel/ ; 06 12462412 ; berend.habekotte@hotmail.com
# https://sport050.nl/sportaanbieders/wij-groningen/ ;  ;
# https://sport050.nl/sportaanbieders/wod-wad-stad/ ;  ; info@wodwadstad.nl
# https://sport050.nl/sportaanbieders/wakepark-groningen/ ; 06 29177109 ; http:info@wakeparkgroningen.nl
# https://sport050.nl/sportaanbieders/wandel-je-fit-door-groningen/ ;  ; sylviataal@gmail.com
# https://sport050.nl/sportaanbieders/waterskiclub-paterswoldsemeer/ ; 050 525 0620 ; info@wscp.nl
# https://sport050.nl/sportaanbieders/werelddansverenigingteu/ ; 0628145663 ; info@teugroningen.nl
# https://sport050.nl/sportaanbieders/wild-wheels-dancing/ ;  ;
# https://sport050.nl/sportaanbieders/wintersport-vereniging-noord-nederland/ ;  ;
# https://sport050.nl/sportaanbieders/womens-self-defense-groningen/ ;  ; womensselfdefensegroningen@gmail.com
# https://sport050.nl/sportaanbieders/word-fitter-personal-training-groningen/ ;  ; wordfitterpt@gmail.com
# https://sport050.nl/sportaanbieders/word-zeemeermin/ ;  ; info@wordzeemeermin.nl
# https://sport050.nl/sportaanbieders/yellow-yoga/ ;  ; info@yellowyoga.nl
# https://sport050.nl/sportaanbieders/yoga-under-construction/ ;  ; info@yogaunderconstruction.nl
# https://sport050.nl/sportaanbieders/yoga050/ ;  ; info@yoga050.nl
# https://sport050.nl/sportaanbieders/yogawieteke/ ; 06-51877048 ; wietekevanmeer@gmail.com
# https://sport050.nl/sportaanbieders/yoo-sin-groningen/ ;  ;
# https://sport050.nl/sportaanbieders/zwem-goud/ ;  ; secretaris@zwemgoud.nl
# https://sport050.nl/sportaanbieders/de-blinkerd/ ; 050-3021747 ; info@zwembadtenboer.nl
# list index out of range
# https://sport050.nl/sportaanbieders/zwemclub-de-duiker/ ; 06 44986549 / 06 51088438 ; jw.meijer@hetnet.nl
# https://sport050.nl/sportaanbieders/zwemclub-noord-oosten/ ; 050-3134852 ; f.nordhauzen@hetnet.nl
# https://sport050.nl/sportaanbieders/zwemschool-aqua-groningen/ ;  ; info@aquagroningen.nl
# https://sport050.nl/sportaanbieders/zwemvereniging-ten-boer/ ;  ; secretariaat@zwemverenigingtenboer.nl
# https://sport050.nl/sportaanbieders/bij-spruit/ ;  ; info@bijspruit.nl
# https://sport050.nl/sportaanbieders/slandsweerbaarheid/ ;  ;
# https://sport050.nl/sportaanbieders/sc-stadspark/ ; 06-54635327 ;
# https://sport050.nl/sportaanbieders/sv-blauw-geel-1915/ ; 050-54 22 718 ;
# https://sport050.nl/sportaanbieders/vv-oosterparkers/ ; Tel: 050 - 314 04 07 ;
# https://sport050.nl/sportaanbieders/vv-potetos/ ;  ;
# https://sport050.nl/sportaanbieders/vv-groningen/ ; 050 364 6643 ;
# https://sport050.nl/sportaanbieders/vv-groninger-boys/ ;  ;

# %%
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup
import ssl
import re

# %%
class Crawler:
    """ 
    This is a crawler program using beautifulsoup.
    It crawls the website "https://sport050.nl/sportaanbieders/alle-aanbieders/"
    and fetches all the sport suppliers in the city of Groningen. It outputs 
    a csv-file with the url;phone-number;email-address of all the suppliers it can find.
    """

    def __init__(self):
        pass
    
    def hack_ssl(self):
        """ ignores the certificate errors"""
        ctx = ssl.create_default_context()
        ctx.check_hostname = False
        ctx.verify_mode = ssl.CERT_NONE
        return ctx


    def open_url(self, url):
        """ reads url file as a big string and cleans the html file to make it
            more readable. input: url, output: soup object
        """
        ctx = hack_ssl()
        html = urllib.request.urlopen(url, context=ctx).read()
        soup = BeautifulSoup(html, 'html.parser')
        return soup


    def read_hrefs(self,soup):
        """ get from soup object a list of anchor tags,
            get the href keys and and prints them. Input: soup object
        """
        reflist = []
        tags = soup('a')
        for tag in tags:
            reflist.append(tag)
        return reflist

    def read_li(self,soup):
        lilist = []
        tags = soup('li')
        for tag in tags:
            lilist.append(tag)
        return lilist

    def get_phone(self,info):
        reg = r"(?:(?:00|\+)?[0-9]{4})?(?:[ .-][0-9]{3}){1,5}"
        phone = [s for s in filter(lambda x: 'Telefoon' in str(x), info)]
        try:
            phone = str(phone[0])
        except:
            phone = [s for s in filter(lambda x: re.findall(reg, str(x)), info)]
            try:
                phone = str(phone[0])
            except:
                phone = ""   
        return phone.replace('Facebook', '').replace('Telefoon:', '')

    def get_email(self,soup):
        try: 
            email = [s for s in filter(lambda x: '@' in str(x), soup)]
            email = str(email[0])[4:-5]
            bs = BeautifulSoup(email, features="html.parser")
            email = bs.find('a').attrs['href'].replace('mailto:', '')
        except:
            email = ""
        return email

    def remove_html_tags(self,text):
        """Remove html tags from a string"""
        clean = re.compile('<.*?>')
        return re.sub(clean, '', text)

    def fetch_sidebar(self,soup):
        """ reads html file as a big string and cleans the html file to make it
            more readable. input: html, output: tables
        """
        sidebar = soup.findAll(attrs={'class': 'sidebar'})
        return sidebar[0]

    def extract(self,url):
        text = str(url)
        text = text[26:].split('"')[0] + "/"
        return text   
    
    sub_urls = [s for s in filter(lambda x: '<a href="/sportaanbieders' in str(x), reflist)]
    sub_urls = sub_urls[3:]
    def crawl_site(self, sub_urls):
        for sub in sub_urls:
            try:
                sub = self.extract(sub)
                site = url[:-16] + sub
                soup = self.open_url(site)    
                info = self.fetch_sidebar(soup)
                info = self.read_li(info)
                phone = self.get_phone(info)
                phone = self.remove_html_tags(phone).strip()
                email = self.get_email(info)
                email = self.remove_html_tags(email).replace("/","")
                return f'{site} ; {phone} ; {email}'
            except Exception as e:
                return e
                exit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 class Crawler:
#       2     """
#       3     This is a crawler program using beautifulsoup.
#       4     It crawls the website "https://sport050.nl/sportaanbieders/alle-aanbieders/"
#       5     and fetches all the sport suppliers in the city of Groningen. It outputs
#       6     a csv-file with the url;phone-number;email-address of all the suppliers it can find.
#       7     """
#       9     def __init__(self):
#
# Cell In [2], line 87, in Crawler()
#      84     text = text[26:].split('"')[0] + "/"
#      85     return text
# ---> 87 sub_urls = [s for s in filter(lambda x: '<a href="/sportaanbieders' in str(x), reflist)]
#      88 sub_urls = sub_urls[3:]
#      89 def crawl_site(self, sub_urls):
#
# NameError: name 'reflist' is not defined
